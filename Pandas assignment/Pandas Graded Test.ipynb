# %% [markdown]
# # Data : 1 'House Rental Data'
# 1. Load rental data with first column as index column (Solved)

# %%
import pandas as pd
import numpy as np

# %%
house_rental = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/house_rental_data.csv.txt',index_col='Unnamed: 0')
house_rental.head()
# Out:
#        Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 1  1177.698      2           7        2            2         2  62000
# 2  2134.800      5           7        4            2         2  78000
# 3  1138.560      5           7        2            2         1  58000
# 4  1458.780      2           7        3            2         2  45000
# 5   967.776     11          14        3            2         2  45000

# %% [markdown]
# # 2. Find all houses which has more than 2 bedroom and price less than 50k¶

# %%
house_rental[(house_rental.Bedroom>2) & (house_rental.Price<50000)]
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 4    1458.780      2           7        3            2         2  45000
# 5     967.776     11          14        3            2         2  45000
# 9    1152.792     10          12        3            2         2  45000
# 13   1352.040      9          19        4            2         2  39000
# 20   1174.140      3           9        3            2         1  33000
# ..        ...    ...         ...      ...          ...       ...    ...
# 634  1167.024      2          12        3            2         2  38000
# 635   996.240      3           5        3            1         1  28000
# 640  1266.648      6           7        3            2         2  40000
# 644  1359.156      7          15        3            2         2  45000
# 648  1376.946      6           7        3            2         1  36000
#
# [138 rows x 7 columns]

# %% [markdown]
# # 3. Find all houses which has more than 3 bedroom and price less than 50k. Update their price with 60k

# %%
def g(a):
    if a.Bedroom>3 and a.Price<50000:
        return 60000
    else: 
        return a.Price
house_rental['new_price']=house_rental.apply(g, axis=1)
house_rental.head()
# Out:
#        Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price  \
# 1  1177.698      2           7        2            2         2  62000
# 2  2134.800      5           7        4            2         2  78000
# 3  1138.560      5           7        2            2         1  58000
# 4  1458.780      2           7        3            2         2  45000
# 5   967.776     11          14        3            2         2  45000
#
#    new_price
# 1    62000.0
# 2    78000.0
# 3    58000.0
# 4    45000.0
# 5    45000.0

# %% [markdown]
# # 4. Find no of house who's price is updated in previous question.

# %%
house_rental[house_rental.Price!=house_rental.new_price]
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price  \
# 13   1352.040      9          19        4            2         2  39000
# 62    889.500      2           4        4            1         1  32000
# 78   1522.824      5          12        4            2         2  40000
# 81   1558.404      5           7        4            2         2  48800
# 137  1921.320      4           7        4            2         2  48000
# 146  1245.300      5           6        4            2         2  39000
# 173  1921.320      4           7        4            2         2  48000
# 182  1487.244      6           7        4            2         2  33700
# 189  1287.996      4           5        4            2         2  30000
# 273  1366.272      4          11        4            2         2  49999
# 308  1871.508     11          12        4            2         2  49999
# 309  1430.316      2           7        4            2         2  44999
# ...

# %% [markdown]
# # 5. Find average price of house.

# %%
means=house_rental[house_rental['Bedroom']==room]['new_price'].mean()
means
# Out:
# 180000.0

# %% [markdown]
# # 6. Find average price of house respective to bedroom.¶

# %%
for room in house_rental.Bedroom.unique():
    means=house_rental[house_rental['Bedroom']==room]['new_price'].mean()
    print("Average price of {} Bedroom house is {}".format(room,means))
# Out:
# Average price of 2 Bedroom house is 47131.68944099379
# Average price of 4 Bedroom house is 80288.93788819876
# Average price of 3 Bedroom house is 65030.94979079498
# Average price of 1 Bedroom house is 35549.086956521736
# Average price of 5 Bedroom house is 117000.0
# Average price of 6 Bedroom house is 180000.0
# Average price of 7 Bedroom house is 180000.0

# %% [markdown]
# # 7. Find details of house whose price is highest.

# %%
maxx=house_rental.Price.max()
house_rental[house_rental.Price==maxx]
# Out:
#         Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom   Price  \
# 289  3504.63     13          14        2            2         2  250000
#
#      new_price
# 289   250000.0

# %% [markdown]
# # 8. Sort the given data by price in ascending order

# %%
house_rental.sort_values("Price",axis = 0, ascending = True, inplace = True, na_position ='last') 
house_rental
# Out:
#         Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom   Price  \
# 613   996.24      4           5        3            2         1    6100
# 408   604.86      5           5        2            0         1   11900
# 624   711.60      1           1        3            1         1   12000
# 375   426.96      9          12        1            0         1   13000
# 276   533.70      7          12        1            1         1   17000
# ..       ...    ...         ...      ...          ...       ...     ...
# 27   3664.74     19          19        3            2         3  200000
# 473  3842.64     15          16        3            1         2  200000
# 303  3664.74      9          13        5            1         2  206000
# 149  4981.20      3          38        3            2         3  225000
# 289  3504.63     13          14        2            2         2  250000
#
#      new_price
# 613     6100.0
# 408    11900.0
# 624    12000.0
# 375    13000.0
# 276    17000.0
# ...

# %% [markdown]
# # 9. Display all details of house with 1 bedroom first then 2 bedroom.. and so on.

# %%
house_data=house_rental.groupby("Bedroom")
house_data.head(20)
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom   Price  \
# 459  1391.178      1           7        1            3         3   50000
# 11    668.904      4          11        1            1         1   31000
# 594   782.760     10          14        1            0         1   31000
# 275   711.600      8          14        1            1         1   36000
# 440   768.528      6           7        1            1         1   45000
# ..        ...    ...         ...      ...          ...       ...     ...
# 570  2383.860      1           7        5            3         3   60000
# 390  2227.308      2           5        5            2         2  100000
# 142  3323.172     19          21        5            3         4  140000
# 576  5856.468      7          21        6            2         5  180000
# 625  4198.440     15          19        7            3         4  180000
#
#      new_price
# 459    50000.0
# 11     31000.0
# 594    31000.0
# 275    36000.0
# ...

# %%
house_data.describe()
# Out:
#           Sqft                                                         \
#          count         mean         std       min       25%       50%
# Bedroom
# 1         69.0   704.896522  325.237204   359.358   523.026   640.440
# 2        161.0  1095.090522  498.594814   434.076   740.064   925.080
# 3        239.0  1675.862661  730.002273   651.114  1184.814  1458.780
# 4        161.0  1945.916609  502.503797   857.478  1572.636  1889.298
# 5         13.0  2808.630462  795.128143  1579.752  2312.700  2700.522
# 6          1.0  5856.468000         NaN  5856.468  5856.468  5856.468
# 7          1.0  4198.440000         NaN  4198.440  4198.440  4198.440
#
#                              Floor             ...     Price            \
#               75%       max  count       mean  ...       75%       max
# Bedroom                                        ...
# 1         782.760  2134.800   69.0   6.304348  ...   43000.0   67000.0
# ...

# %% [markdown]
# # 10. Display all details of each house with 1 bedroom first then 2 bedroom.. and so on.

# %%
house_rental.sort_values("Bedroom",ascending=True,axis=0,inplace=True)
house_rental
# Out:
#          Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom   Price  \
# 459  1391.178      1           7        1            3         3   50000
# 432   925.080      2          18        1            2         1   51000
# 65    391.380      5           7        1            1         1   27500
# 69    462.540      6          14        1            1         1   27500
# 520   587.070      5           7        1            1         1   36000
# ..        ...    ...         ...      ...          ...       ...     ...
# 511  2028.060     12          12        5            1         1   89000
# 108  3202.200     12          12        5            3         3   80000
# 331  2892.654     19          21        5            3         4  170000
# 576  5856.468      7          21        6            2         5  180000
# 625  4198.440     15          19        7            3         4  180000
#
#      new_price
# 459    50000.0
# 432    51000.0
# 65     27500.0
# 69     27500.0
# ...

# %% [markdown]
# # Data : 2 'Health Care Data'
# Load rental data with first column as index column (Solved)

# %%
hc_df = pd.read_excel('HealthCareData-1.xlsx')
hc_df
# Out:
#      S.NO  Age   Gender Place(location where the patient lives)  \
# 0       1   55     male                                   rural
# 1       2   55     male                                   rural
# 2       3   55     male                                   rural
# 3       4   55     male                                   rural
# 4       5   55   female                                   rural
# ..    ...  ...      ...                                     ...
# 945   946   54  female                                    rural
# 946   947   72  female                                    urban
# 947   948   47     male                                   urban
# 948   949   54  female                                    rural
# 949   950   52     male                                   rural
#
#      Duration of alcohol consumption(years)  \
# 0                                        12
# 1                                        12
# 2                                        12
# ...

# %% [markdown]
# # 1. Display all the information respective to gender.

# %%
question not clear

# %% [markdown]
# # 2. Find all the male who is consuming alcohal more than 5 years and has diabetes result positive.

# %%
hc_df[(hc_df.Gender=='male') & (hc_df['Duration of alcohol consumption(years)']>5) & (hc_df['Diabetes Result']=='YES')].head(15)
# Out:
#     S.NO  Age Gender Place(location where the patient lives)  \
# 0      1   55   male                                   rural
# 1      2   55   male                                   rural
# 2      3   55   male                                   rural
# 5      6   55   male                                   urban
# 6      7   55   male                                   urban
# 7      8   55   male                                   rural
# 8      9   55   male                                   rural
# 9     10   55   male                                   rural
# 10    11   45   male                                   urban
# 11    12   44   male                                   urban
# 12    13   45   male                                   urban
# 13    14   44   male                                   urban
# 14    15   45   male                                   urban
# 15    16   44   male                                   urban
# ...

# %% [markdown]
# # 3. Find where more people consume alcohol in rural or urban?

# %%
urban=hc_df[(hc_df['Place(location where the patient lives)']=='urban') & (hc_df['Duration of alcohol consumption(years)']>1)]['S.NO'].count()
rural=hc_df[(hc_df['Place(location where the patient lives)']=='rural') & (hc_df['Duration of alcohol consumption(years)']>1)]['S.NO'].count()
print("urban= {} and rural= {}".format(urban,rural))
# Out:
# urban= 362 and rural= 453

# %% [markdown]
# # 4. Find average age of male and female who consume alcohol.

# %%
hc_df[hc_df['Duration of alcohol consumption(years)']>1]['Age'].mean()
# Out:
# 50.63263157894737

# %% [markdown]
# # 5. Display distribution for different type of alcohol.

# %%
for peg in hc_df['Type of alcohol consumed'].unique():
    counting=hc_df[hc_df['Type of alcohol consumed']==peg]['S.NO'].count()
    print("{} is consumed by {} people".format(peg.strip(),counting))
# Out:
# branded liquor is consumed by 183 people
# both is consumed by 288 people
# country liquor is consumed by 478 people
# branded liquor is consumed by 1 people

# %% [markdown]
# # 6. Display average age of perople who has diabetes positive.

# %%
hc_df[hc_df['Diabetes Result']=='YES'].Age.mean()
# Out:
# 50.68006182380216

# %% [markdown]
# # 7. Find is there any missing value of age in given data.

# %%
hc_df.info()
print("No missing value in Age since it has non-null")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 42 columns):
# S.NO                                                                       950 non-null int64
# Age                                                                        950 non-null int64
# Gender                                                                     950 non-null object
# Place(location where the patient lives)                                    816 non-null object
# Duration of alcohol consumption(years)                                     950 non-null int64
# Quantity of alcohol consumption (quarters/day)                             950 non-null int64
# Type of alcohol consumed                                                   950 non-null object
# Hepatitis B infection                                                      950 non-null object
# Hepatitis C infection                                                      950 non-null object
# ...

# %% [markdown]
# # 8. If gender is male and age is less than 35 then change diabetes result to NO .

# %%
new_hc_df=hc_df.copy()

# %%
new_hc_df.replace(to_replace=new_hc_df[(new_hc_df.Gender=='male') & (new_hc_df.Age<35)],value='NO')
# Out:
#      S.NO  Age   Gender Place(location where the patient lives)  \
# 0       1   55     male                                   rural
# 1       2   55     male                                   rural
# 2       3   55     male                                   rural
# 3       4   55     male                                   rural
# 4       5   55   female                                   rural
# ..    ...  ...      ...                                     ...
# 945   946   54  female                                    rural
# 946   947   72  female                                    urban
# 947   948   47     male                                   urban
# 948   949   54  female                                    rural
# 949   950   52     male                                   rural
#
#      Duration of alcohol consumption(years)  \
# 0                                        12
# 1                                        12
# 2                                        12
# ...

# %%
#check to see if any value is missed
new_hc_df[(new_hc_df.Gender=='male') & (new_hc_df.Age<35) & (new_hc_df['Diabetes Result']=='YES')]
# Out:
# Empty DataFrame
# Columns: [S.NO, Age, Gender, Place(location where the patient lives), Duration of alcohol consumption(years), Quantity of alcohol consumption (quarters/day), Type of alcohol consumed, Hepatitis B infection, Hepatitis C infection, Diabetes Result, Blood pressure (mmhg), Obesity, Family history of cirrhosis/ hereditary, TCH, TG, LDL, HDL, Hemoglobin  (g/dl), PCV  (%), RBC  (million cells/microliter), MCV   (femtoliters/cell), MCH  (picograms/cell), MCHC  (grams/deciliter), Total Count, Polymorphs  (%) , Lymphocytes  (%), Monocytes   (%), Eosinophils   (%), Basophils  (%), Platelet Count  (lakhs/mm), Total Bilirubin    (mg/dl), Direct    (mg/dl), Indirect     (mg/dl), Total Protein     (g/dl), Albumin   (g/dl), Globulin  (g/dl), A/G Ratio, AL.Phosphatase      (U/L), SGOT/AST      (U/L), SGPT/ALT (U/L), USG Abdomen (diffuse liver or  not), Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# # 9. Find all record where Place is missing.

# %%
hc_df[hc_df['Place(location where the patient lives)'].isnull()]
# Out:
#      S.NO  Age  Gender Place(location where the patient lives)  \
# 190   191   50    male                                     NaN
# 198   199   50    male                                     NaN
# 199   200   44    male                                     NaN
# 245   246   42    male                                     NaN
# 295   296   46    male                                     NaN
# ..    ...  ...     ...                                     ...
# 877   878   38    male                                     NaN
# 911   912   50    male                                     NaN
# 917   918   50  female                                     NaN
# 927   928   50    male                                     NaN
# 929   930   50    male                                     NaN
#
#      Duration of alcohol consumption(years)  \
# 190                                      28
# 198                                      28
# 199                                      25
# ...

# %% [markdown]
# # 10. Change place to urban if gender is female else rural.

# %%
hc_df.replace(to_replace=hc_df[(hc_df.Gender=='female') & (hc_df['Place(location where the patient lives)']=='rural')]['Place(location where the patient lives)'],
                                 value='urban')
# Out:
#      S.NO  Age   Gender Place(location where the patient lives)  \
# 0       1   55     male                                   rural
# 1       2   55     male                                   rural
# 2       3   55     male                                   rural
# 3       4   55     male                                   rural
# 4       5   55   female                                   rural
# ..    ...  ...      ...                                     ...
# 945   946   54  female                                    rural
# 946   947   72  female                                    urban
# 947   948   47     male                                   urban
# 948   949   54  female                                    rural
# 949   950   52     male                                   rural
#
#      Duration of alcohol consumption(years)  \
# 0                                        12
# 1                                        12
# 2                                        12
# ...
